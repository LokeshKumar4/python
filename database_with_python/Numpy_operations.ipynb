# %%
**Numpy**

import numpy as np

#scalar 
x=5


#vector 
vector1= np.array([1,2,3,4])
vector1

np.array((3,4,5,6))

type(vector1)

matrix1=np.array([[4,3,2],[3,2,5]])

matrix1

matrix1.shape

vector1.shape

'''create 2 matrices , the matrices should have the same dimension and call matrix 1 + matrix 2
'''

matrix1=np.array([[1,2,3],[8,4,3]])
matrix2=np.array([[9,9,1],[1,6,3]])

matrix1+matrix2

matrix1*matrix2

matrix1*2

m1=np.array([[2,6],[4,8]])
m2=np.array([[4,2],[7,9]])
m1.dot(m2)

m2.dot(m1)

matrix2=matrix2.reshape(3,2)

matrix1.dot(matrix2)

matrix1[0][0]=3.14
matrix1

np.arange(1,6)

arr1=np.arange(1,6,2)



arr1.shape

arr1=np.arange(1,26,2)
arr1

**Pandas**

'''
we have :
        series => a single column table
        data frame => 
        
'''        

import pandas as pd

data= pd.Series([10,20,30])

data

type(data)

data2=pd.Series(["a","b","c"])
type(data2)

print(data.sum())

data.max()

data.idxmax()

data.idxmin()

v1=np.array([1,2,3,4])

d=pd.Series(v1)

d
d.dtype

pd.DataFrame({"user":"Tushar","marks":100},index=[0])

pd.DataFrame({"user":["Tushar","Lokesh"],"marks":100})

#row lable index => givrn by the user

import collections
# Create a deque
DoubleEnded = collections.deque(["Mon","Tue","Wed"])
print (DoubleEnded)

# Append to the right
print("Adding to the right: ")
DoubleEnded.append("Thu")
print (DoubleEnded)

# append to the left
print("Adding to the left: ")
DoubleEnded.appendleft("Sun")
print (DoubleEnded)

# Remove from the right
print("Removing from the right: ")
DoubleEnded.pop()
print (DoubleEnded)

# Remove from the left
print("Removing from the left: ")
DoubleEnded.popleft()
print (DoubleEnded)

# Reverse the dequeue
print("Reversing the deque: ")
DoubleEnded.reverse()
print (DoubleEnded)

import pandas as pd
pokemon=pd.read_csv("pokemo")
# Out:
#   File "C:\Users\futurense.MILE-BL-4171-LA\AppData\Local\Temp\ipykernel_15284\4247871818.py", line 1
#     **Numpy**
#     ^
# SyntaxError: invalid syntax
