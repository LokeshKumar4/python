# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14032\413465007.py in <module>
# ----> 1 df=pd.read_csv("")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df2=df.groupby("Item").mean().reset_index()
df2
# Out:
#         Item      Spend
# 0     Burger  49.780321
# 1    Burrito  49.228810
# 2    Chalupa  52.003537
# 3      Donut  46.838289
# 4  Ice Cream  50.494261
# 5      Sushi  52.668253

# %%
plt.figure(figsize=(6,3))
           
plt.bar(x=df2['Item'],height=df2['Spend'],color=["skyblue","red"])
plt.ylabel("Spending")
plt.xlabel("Items")
plt.title("fast food expenditure")
plt.ylim(0,60)
# Out:
# (0.0, 60.0)

# %%
plt.pie(df2["Spend"],labels=df2['Item'].values,autopct='%.2f')

plt.show()

# %%
df=pd.read_csv("bar_chart/bar_chart_data.csv")

# %%
df
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize=(6,3))
           
plt.bar(x=df['Brand'],height=df['Cars Listings']/10,color=["skyblue","red"])
plt.ylabel("Cars Listings")
plt.xlabel("Brands")
plt.title("Cars Brand")
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
df=pd.read_csv("Stack_chart/stacked_area_chart_data.csv")

# %%
plt.stackplot(df["Year"],df['Diesel'],df['Gas'],df['Petrol'])

# %%
plt.stackplot(df["Year"],df['Gas'],df['Diesel'],df['Petrol'])
