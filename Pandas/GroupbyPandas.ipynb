# %%
import pandas as pd

# %%
df=pd.read_csv("userfoods.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  1000 non-null   object
#  1   Gender      1000 non-null   object
#  2   City        1000 non-null   object
#  3   Frequency   1000 non-null   object
#  4   Item        1000 non-null   object
#  5   Spend       1000 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 47.0+ KB

# %%
df["Spend"].mean()
# Out:
# 50.06937

# %%
df[df["Gender"]=="Male"]["Spend"].mean()
# Out:
# 49.39762295081966

# %%
df[df["Gender"]=="Female"]["Spend"].mean()
# Out:
# 50.709628906249996

# %%
genderGrouped=df.groupby("Gender")

# %%
genderGrouped

# %%
genderGrouped.get_group("Male")
# Out:
#     First Name Gender          City Frequency       Item  Spend
# 1         Eric   Male      Stamford     Daily    Chalupa  10.56
# 2      Charles   Male      New York     Never      Sushi  42.14
# 5      Charles   Male      Stamford   Monthly      Sushi  93.03
# 6         Mark   Male  Philadelphia   Monthly  Ice Cream  30.01
# 7         Paul   Male  Philadelphia   Monthly    Chalupa  17.65
# ..         ...    ...           ...       ...        ...    ...
# 991    Anthony   Male      Stamford    Yearly  Ice Cream   8.72
# 992    Raymond   Male      New York     Never     Burger  90.32
# 993       Mark   Male  Philadelphia    Seldom      Donut  13.79
# 996     Albert   Male  Philadelphia     Daily      Sushi  72.88
# 999      Brian   Male      New York     Daily    Chalupa  28.36
#
# [488 rows x 6 columns]

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Female    512
# Male      488
# Name: Gender, dtype: int64

# %%
len(genderGrouped)
# Out:
# 2

# %%
genderGrouped.size()
# Out:
# Gender
# Female    512
# Male      488
# dtype: int64

# %%
df=pd.read_csv("fortune_data.csv")
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df.drop("Rank",axis=1)
# Out:
#                         Company                        Sector  \
# 0                       Walmart                     Retailing
# 1                   Exxon Mobil                        Energy
# 2                         Apple                    Technology
# 3            Berkshire Hathaway                    Financials
# 4                      McKesson                   Health Care
# ..                          ...                           ...
# 995  New York Community Bancorp                    Financials
# 996   Portland General Electric                        Energy
# 997   Portland General Electric                        Energy
# 998                     Wendy’s  Hotels, Resturants & Leisure
# 999           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df["Sector"].unique()
# Out:
# array(['Retailing', 'Energy', 'Technology', 'Financials', 'Health Care',
#        'Food and Drug Stores', 'Motor Vehicles & Parts',
#        'Telecommunications', 'Industrials', 'Aerospace & Defense',
#        'Household Products', 'Food, Beverages & Tobacco',
#        'Transportation', 'Media', 'Chemicals', 'Wholesalers', 'Apparel',
#        'Hotels, Resturants & Leisure', 'Materials', 'Business Services',
#        'Engineering & Construction'], dtype=object)

# %%
g=df.groupby("Sector")

# %%
len(g)
# Out:
# 21

# %%
g.get_group("Retailing")
# Out:
#      Rank                         Company     Sector  \
# 0       1                         Walmart  Retailing
# 14     15                          Costco  Retailing
# 27     28                      Home Depot  Retailing
# 37     38                          Target  Retailing
# 46     47                          Lowe’s  Retailing
# ..    ...                             ...        ...
# 898   899  Sears Hometown & Outlet Stores  Retailing
# 921   922                       Outerwall  Retailing
# 936   937                         hhgregg  Retailing
# 939   940            Restoration Hardware  Retailing
# 972   973            99 Cents Only Stores  Retailing
#
#                        Industry             Location  Revenue  Profits  \
# 0         General Merchandisers      Bentonville, AR   482130    14694
# 14   Specialty Retailers: Other         Issaquah, WA   116199     2377
# 27   Specialty Retailers: Other          Atlanta, GA    88519     7009
# ...

# %%
g.max()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense            987                Woodward
# Apparel                        917    Wolverine World Wide
# Business Services              993           Western Union
# Chemicals                      949       Westlake Chemical
# Energy                         997             Xcel Energy
# Engineering & Construction     994            Tutor Perini
# Financials                     996          Zions Bancorp.
# Food and Drug Stores           928      Whole Foods Market
# Food, Beverages & Tobacco      954         WhiteWave Foods
# Health Care                    978         inVentiv Health
# Hotels, Resturants & Leisure   999              Yum Brands
# Household Products             992           Vista Outdoor
# Industrials                   1000      Zebra Technologies
# Materials                      986  Worthington Industries
# Media                          989             iHeartMedia
# ...

# %%
g["Revenue"].max()
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
g.get_group({"Revenue":"max","Profits":"min"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11740\847562578.py in <module>
# ----> 1 g.get_group({"Revenue":"max","Profits":"min"})
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     743             obj = self._selected_obj
#     744
# --> 745         inds = self._get_index(name)
#     746         if not len(inds):
#     747             raise KeyError(name)
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_index(self, name)
#     671         Safe get index, translate keys for datelike to underlying repr.
#     672         """
# --> 673         return self._get_indices([name])[0]
#     674
#     675     @final
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_indices(self, names)
#     664             names = (converter(name) for name in names)
# ...

# %%
df=pd.read_csv("fortune_data.csv")
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df["Country"]=df["Location"].str.split(",").str.get(1)

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df=pd.read_csv("fortune_data2.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11740\3883437480.py in <module>
# ----> 1 df=pd.read_csv("fortune_data2.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
df["Country"]=df["Location"].str.split(",").str.get(1)

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
"banglorw".split(",").[1]
# Out:
#   File "C:\Users\futurense.MILE-BL-4171-LA\AppData\Local\Temp\ipykernel_12760\501662793.py", line 1
#     "banglorw".split(",").[1]
#                           ^
# SyntaxError: invalid syntax

# %%
def func(a):
    if "AR" in a or "NY" in a or "CA" in a:
        return 0
    return 1

# %%
df["Country"]=df["Country"].apply(func)

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
'''Concat'''
# Out:
# 'Concat'

# %%
df1=pd.DataFrame([[10,20,30],[40,50,60]])

# %%
df1
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60

# %%
df2=pd.DataFrame([[70,80,90],[100,110,120]])

# %%
df2
# Out:
#      0    1    2
# 0   70   80   90
# 1  100  110  120

# %%
pd.concat(objs=[df1,df2])
# Out:
#      0    1    2
# 0   10   20   30
# 1   40   50   60
# 0   70   80   90
# 1  100  110  120

# %%
pd.concat(objs=[df1,df2],axis=1)
# Out:
#     0   1   2    0    1    2
# 0  10  20  30   70   80   90
# 1  40  50  60  100  110  120

# %%
pd.concat(objs=[df1,df2],ignore_index=True)
# Out:
#      0    1    2
# 0   10   20   30
# 1   40   50   60
# 2   70   80   90
# 3  100  110  120

# %%
'''
concat is in pandas 
append is used with data frame
'''
# Out:
# '\nconcat is in pandas \nappend is used with data frame\n'

# %%
df=pd.read_csv("ml-latest-small/ratings.csv")

# %%
# df.index=df["movieId"]

# %%
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
# import datetime
df["timestamp"]=pd.to_datetime(df["timestamp"],unit='s')

# %%
df2=pd.read_csv("ml-latest-small/movies.csv")

# %%
df
# Out:
#         userId  movieId  rating           timestamp
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
# [100836 rows x 4 columns]

# %% [markdown]
# ##

# %%
df2
# Out:
#        movie                                      title  \
# 0          1                           Toy Story (1995)
# 1          2                             Jumanji (1995)
# 2          3                    Grumpier Old Men (1995)
# 3          4                   Waiting to Exhale (1995)
# 4          5         Father of the Bride Part II (1995)
# ...      ...                                        ...
# 9737  193581  Black Butler: Book of the Atlantic (2017)
# 9738  193583               No Game No Life: Zero (2017)
# 9739  193585                               Flint (2017)
# 9740  193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741  193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
a=pd.concat(objs=[df,df2],axis=1)

# %%
merged_inner = pd.merge(left=df, right=df2,how='inner', left_on='movie', right_on='movie')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12760\2228519535.py in <module>
# ----> 1 merged_inner = pd.merge(left=df, right=df2,how='inner', left_on='movie', right_on='movie')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     698             self.right_join_keys,
#     699             self.join_names,
# --> 700         ) = self._get_merge_keys()
#     701
# ...

# %% [raw]
# merged_inner.info()

# %%
merged_inner
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12760\2422861314.py in <module>
# ----> 1 merged_inner
#
# NameError: name 'merged_inner' is not defined

# %%
a
# Out:
#         userId  movieId  rating           timestamp  movie  \
# 0            1        1     4.0 2000-07-30 18:45:03    1.0
# 1            1        3     4.0 2000-07-30 18:20:47    2.0
# 2            1        6     4.0 2000-07-30 18:37:04    3.0
# 3            1       47     5.0 2000-07-30 19:03:35    4.0
# 4            1       50     5.0 2000-07-30 18:48:51    5.0
# ...        ...      ...     ...                 ...    ...
# 100831     610   166534     4.0 2017-05-03 21:53:22    NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31    NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47    NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12    NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15    NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# 2                  Grumpier Old Men (1995)
# 3                 Waiting to Exhale (1995)
# ...

# %%
df3=pd.read_csv("ml-latest-small/tags.csv")

# %%
df3
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
pd.merge(left=df,right=df3,on=["userId","movieId"]).head(10)
# Out:
#    userId  movieId  rating         timestamp_x                tag  timestamp_y
# 0       2    60756     5.0 2015-10-24 19:29:40              funny   1445714994
# 1       2    60756     5.0 2015-10-24 19:29:40    Highly quotable   1445714996
# 2       2    60756     5.0 2015-10-24 19:29:40       will ferrell   1445714992
# 3       2    89774     5.0 2015-10-24 19:33:09       Boxing story   1445715207
# 4       2    89774     5.0 2015-10-24 19:33:09                MMA   1445715200
# 5       2    89774     5.0 2015-10-24 19:33:09          Tom Hardy   1445715205
# 6       2   106782     5.0 2015-10-24 19:29:26              drugs   1445715054
# 7       2   106782     5.0 2015-10-24 19:29:26  Leonardo DiCaprio   1445715051
# 8       2   106782     5.0 2015-10-24 19:29:26    Martin Scorsese   1445715056
# 9       7    48516     1.0 2007-01-25 01:08:38       way too long   1169687325

# %%
j1=df.merge(df3,on=["userId","movieId"])
j1
# Out:
#       userId  movieId  rating         timestamp_x               tag  \
# 0          2    60756     5.0 2015-10-24 19:29:40             funny
# 1          2    60756     5.0 2015-10-24 19:29:40   Highly quotable
# 2          2    60756     5.0 2015-10-24 19:29:40      will ferrell
# 3          2    89774     5.0 2015-10-24 19:33:09      Boxing story
# 4          2    89774     5.0 2015-10-24 19:33:09               MMA
# ...      ...      ...     ...                 ...               ...
# 3471     606     6107     4.0 2007-02-12 23:53:48      World War II
# 3472     606     7382     4.5 2007-02-11 22:45:24         for katie
# 3473     610     3265     5.0 2016-11-19 07:53:30            gun fu
# 3474     610     3265     5.0 2016-11-19 07:53:30  heroic bloodshed
# 3475     610   168248     5.0 2017-05-03 22:21:31  Heroic Bloodshed
#
#       timestamp_y
# 0      1445714994
# 1      1445714996
# 2      1445714992
# 3      1445715207
# 4      1445715200
# ...           ...
# ...

# %%
finaljoin=j1.merge(df2,left_on="movieId",right_on="movie")

# %%
finaljoin
# Out:
#       userId  movieId  rating         timestamp_x               tag  \
# 0          2    60756     5.0 2015-10-24 19:29:40             funny
# 1          2    60756     5.0 2015-10-24 19:29:40   Highly quotable
# 2          2    60756     5.0 2015-10-24 19:29:40      will ferrell
# 3         62    60756     3.5 2018-06-13 23:59:36            comedy
# 4         62    60756     3.5 2018-06-13 23:59:36             funny
# ...      ...      ...     ...                 ...               ...
# 3471     606     1948     3.5 2007-04-25 14:50:39           British
# 3472     606     5694     3.0 2007-03-04 00:42:52              70mm
# 3473     606     6107     4.0 2007-02-12 23:53:48      World War II
# 3474     610     3265     5.0 2016-11-19 07:53:30            gun fu
# 3475     610     3265     5.0 2016-11-19 07:53:30  heroic bloodshed
#
#       timestamp_y  movie                                              title  \
# ...

# %%
# import datetime
finaljoin["timestamp_y"]=pd.to_datetime(finaljoin["timestamp_y"],unit='s')

# %%
'''
1. how many numbers of movies has been watcheded userid more than 10 , the user should have watched at least 10 movies
2. find out the number of movies who has beeen given the rating more than 3 after 2007
3. find out the average total number of movies for each tag
4. find out how many number of movies for each joiner of  action and comedy
'''
# Out:
# '\n1. how many numbers of movies has been watcheded userid more than 10 , the user should have watched at least 10 movies\n2. find out the number of movies who has beeen given the rating more than 3 after 2007\n3. find out the average total number of movies for each tag\n4. find out how many number of movies for each joiner of  action and comedy\n'

# %%
finaljoin
# Out:
#       userId  movieId  rating         timestamp_x               tag  \
# 0          2    60756     5.0 2015-10-24 19:29:40             funny
# 1          2    60756     5.0 2015-10-24 19:29:40   Highly quotable
# 2          2    60756     5.0 2015-10-24 19:29:40      will ferrell
# 3         62    60756     3.5 2018-06-13 23:59:36            comedy
# 4         62    60756     3.5 2018-06-13 23:59:36             funny
# ...      ...      ...     ...                 ...               ...
# 3471     606     1948     3.5 2007-04-25 14:50:39           British
# 3472     606     5694     3.0 2007-03-04 00:42:52              70mm
# 3473     606     6107     4.0 2007-02-12 23:53:48      World War II
# 3474     610     3265     5.0 2016-11-19 07:53:30            gun fu
# 3475     610     3265     5.0 2016-11-19 07:53:30  heroic bloodshed
#
#              timestamp_y  movie  \
# 0    2015-10-24 19:29:54  60756
# 1    2015-10-24 19:29:56  60756
# 2    2015-10-24 19:29:52  60756
# ...

# %%
c1=finaljoin.copy()

# %%
# c1.query('userId>10',inplace=True )
# c2=c1.groupby("userId")
# c2.where(c2["movieId"]>10)
c1= c1.loc[c1["userId"]>10].groupby(["userId"]).count()

# %%
c1.loc[c1["movieId"]>10]
# Out:
#         movieId  rating  timestamp_x   tag  timestamp_y  movie  title  genres
# userId
# 18           16      16           16    16           16     16     16      16
# 62          367     367          367   367          367    367    367     367
# 119          12      12           12    12           12     12     12      12
# 125          48      48           48    48           48     48     48      48
# 184          35      35           35    35           35     35     35      35
# 193          17      17           17    17           17     17     17      17
# 318          36      36           36    36           36     36     36      36
# 357          45      45           45    45           45     45     45      45
# 424         223     223          223   223          223    223    223     223
# 474        1409    1409         1409  1409         1409   1409   1409    1409
# 477         267     267          267   267          267    267    267     267
# ...

# %% [markdown]
# #

# %%
finaljoin.loc[c1["movieId"]]
# Out:
#       userId  movieId  rating         timestamp_x                tag  \
# 16         7    48516     1.0 2007-01-25 01:08:38       way too long
# 1          2    60756     5.0 2015-10-24 19:29:40    Highly quotable
# 3         62    60756     3.5 2018-06-13 23:59:36             comedy
# 367       62   128360     5.0 2018-03-19 20:04:37            Western
# 2          2    60756     5.0 2015-10-24 19:29:40       will ferrell
# 2          2    60756     5.0 2015-10-24 19:29:40       will ferrell
# 5         62    60756     3.5 2018-06-13 23:59:36       will ferrell
# 2          2    60756     5.0 2015-10-24 19:29:40       will ferrell
# 3         62    60756     3.5 2018-06-13 23:59:36             comedy
# 12         2   106782     5.0 2015-10-24 19:29:26  Leonardo DiCaprio
# 48        62   119141     3.0 2018-05-05 21:18:43       James Franco
# 4         62    60756     3.5 2018-06-13 23:59:36              funny
# 2          2    60756     5.0 2015-10-24 19:29:40       will ferrell
# ...

# %%
'''
1. how many numbers of movies has been watcheded userid more than 10 , the user should have watched at least 10 movies
'''
# Out:
# '\n1. how many numbers of movies has been watcheded userid more than 10 , the user should have watched at least 10 movies\n'

# %%
'''
2. find out the number of movies who has beeen given the rating more than 3 after 2007

'''
f1=finaljoin.copy()
f1["timestamp_x"]=pd.to_datetime(f1['timestamp_x'],unit='s')
f1=f1.query('rating>3 ')

# %%
f1
# Out:
#       userId  movieId  rating         timestamp_x               tag  \
# 0          2    60756     5.0 2015-10-24 19:29:40             funny
# 1          2    60756     5.0 2015-10-24 19:29:40   Highly quotable
# 2          2    60756     5.0 2015-10-24 19:29:40      will ferrell
# 3         62    60756     3.5 2018-06-13 23:59:36            comedy
# 4         62    60756     3.5 2018-06-13 23:59:36             funny
# ...      ...      ...     ...                 ...               ...
# 3470     606     1357     4.0 2007-03-13 22:10:37             music
# 3471     606     1948     3.5 2007-04-25 14:50:39           British
# 3473     606     6107     4.0 2007-02-12 23:53:48      World War II
# 3474     610     3265     5.0 2016-11-19 07:53:30            gun fu
# 3475     610     3265     5.0 2016-11-19 07:53:30  heroic bloodshed
#
#              timestamp_y  movie  \
# 0    2015-10-24 19:29:54  60756
# 1    2015-10-24 19:29:56  60756
# 2    2015-10-24 19:29:52  60756
# ...

# %%
f1["year"]=f1["title"].str.split("(").str.get(-1).str.replace(")","")
# Out:
# C:\Users\futurense.MILE-BL-4171-LA\AppData\Local\Temp\ipykernel_12760\410070675.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   f1["year"]=f1["title"].str.split("(").str.get(-1).str.replace(")","")

# %%
f1["year"]=pd.to_numeric(f1["year"], errors='coerce').convert_dtypes()

# %%
f1["year"].dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11740\3004513607.py in <module>
# ----> 1 f1["year"].dropna()
#
# NameError: name 'f1' is not defined

# %%
f1
# Out:
#       userId  movieId  rating         timestamp_x               tag  \
# 0          2    60756     5.0 2015-10-24 19:29:40             funny
# 1          2    60756     5.0 2015-10-24 19:29:40   Highly quotable
# 2          2    60756     5.0 2015-10-24 19:29:40      will ferrell
# 3         62    60756     3.5 2018-06-13 23:59:36            comedy
# 4         62    60756     3.5 2018-06-13 23:59:36             funny
# ...      ...      ...     ...                 ...               ...
# 3470     606     1357     4.0 2007-03-13 22:10:37             music
# 3471     606     1948     3.5 2007-04-25 14:50:39           British
# 3473     606     6107     4.0 2007-02-12 23:53:48      World War II
# 3474     610     3265     5.0 2016-11-19 07:53:30            gun fu
# 3475     610     3265     5.0 2016-11-19 07:53:30  heroic bloodshed
#
#              timestamp_y  movie  \
# 0    2015-10-24 19:29:54  60756
# 1    2015-10-24 19:29:56  60756
# 2    2015-10-24 19:29:52  60756
# ...

# %%
f1.loc[f1["year"]>2007]
# Out:
#       userId  movieId  rating         timestamp_x              tag  \
# 0          2    60756     5.0 2015-10-24 19:29:40            funny
# 1          2    60756     5.0 2015-10-24 19:29:40  Highly quotable
# 2          2    60756     5.0 2015-10-24 19:29:40     will ferrell
# 3         62    60756     3.5 2018-06-13 23:59:36           comedy
# 4         62    60756     3.5 2018-06-13 23:59:36            funny
# ...      ...      ...     ...                 ...              ...
# 3451     567   176371     5.0 2018-05-02 17:27:43   existentialism
# 3452     567   176371     5.0 2018-05-02 17:27:43            moody
# 3453     567   176371     5.0 2018-05-02 17:27:43    philosophical
# 3457     567   180031     4.0 2018-05-02 18:02:23      atmospheric
# 3458     567   180031     4.0 2018-05-02 18:02:23        dreamlike
#
#              timestamp_y   movie                      title  \
# 0    2015-10-24 19:29:54   60756       Step Brothers (2008)
# ...

# %%
'''
3. find out the average total number of movies for each tag

'''
a=finaljoin.groupby('genres')['movieId'].count()

# %%
a
# Out:
# genres
# (no genres listed)                                     3
# Action|Adventure                                       6
# Action|Adventure|Animation|Children|Comedy             4
# Action|Adventure|Animation|Children|Comedy|Fantasy     7
# Action|Adventure|Animation|Children|Comedy|Sci-Fi      1
#                                                       ..
# Romance|War                                            2
# Sci-Fi                                                15
# Sci-Fi|IMAX                                            7
# Thriller                                              12
# Western                                               14
# Name: movieId, Length: 364, dtype: int64

# %%
finaljoin.where(finaljoin["genres"]=="Action")
# Out:
#       userId  movieId  rating timestamp_x  tag timestamp_y  movie title genres
# 0        NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 1        NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 2        NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 3        NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 4        NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# ...      ...      ...     ...         ...  ...         ...    ...   ...    ...
# 3471     NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 3472     NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 3473     NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 3474     NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
# 3475     NaN      NaN     NaN         NaT  NaN         NaT    NaN   NaN    NaN
#
# [3476 rows x 9 columns]

# %% [markdown]
# ######

# %%
g2.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8776\2359605916.py in <module>
# ----> 1 g2.unique()
#
# AttributeError: 'function' object has no attribute 'unique'

# %%
'''
1. to create a data frame by raeding a particular .
2. update changes to sql



'''
